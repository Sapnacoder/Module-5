# %%
# !pip install yfinance
# !pip install pandas
# !pip install requests
# !pip install beautifulsoup4
# !pip install matplotlib
# Out:
# ...
#                                               0.0/63.0 kB ? eta -:--:--
#      ---------------------------------------- 63.0/63.0 kB 1.7 MB/s eta 0:00:00
# ...
#                                               0.0/10.6 MB ? eta -:--:--
#                                               0.1/10.6 MB 4.8 MB/s eta 0:00:03
#                                               0.2/10.6 MB 2.1 MB/s eta 0:00:05
#      -                                        0.3/10.6 MB 2.1 MB/s eta 0:00:05
#      -                                        0.4/10.6 MB 2.2 MB/s eta 0:00:05
#      --                                       0.6/10.6 MB 2.5 MB/s eta 0:00:05
#      --                                       0.6/10.6 MB 2.4 MB/s eta 0:00:05
#      --                                       0.7/10.6 MB 2.3 MB/s eta 0:00:05
#      ---                                      0.8/10.6 MB 2.3 MB/s eta 0:00:05
#      ---                                      1.0/10.6 MB 2.3 MB/s eta 0:00:05
# ...

# %%
import yfinance as yf

# Define the ticker symbol for Tesla
tesla_ticker = 'TSLA'

# Extract Tesla stock data from Yahoo Finance
tesla_stock_data = yf.download(tesla_ticker, start='2020-01-01', end='2023-07-01')

# Display the first few rows of the stock data
print(tesla_stock_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500

# %%
import requests
from bs4 import BeautifulSoup

# Replace the URL with the actual website containing Tesla revenue data
url_tesla_revenue = 'https://example.com/tesla-revenue'

# Send an HTTP GET request to the URL
response = requests.get(url_tesla_revenue)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find the revenue data in the HTML and extract it
# For example, if the revenue is in a table, you would use appropriate HTML tags to extract the data
# revenue_data = soup.find('table').find('td', class_='revenue').text

# %%
# Define the ticker symbol for GameStop
gamestop_ticker = 'GME'

# Extract GameStop stock data from Yahoo Finance
gamestop_stock_data = yf.download(gamestop_ticker, start='2020-01-01', end='2023-07-01')

# Display the first few rows of the stock data
print(gamestop_stock_data.head())

# %%
# Define the URL to fetch GameStop's revenue data
gamestop_revenue_url = 'https://example.com/gamestop-revenue-page'  # Replace with the actual URL

# Send an HTTP request to the website and parse the HTML content
response = requests.get(gamestop_revenue_url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find the revenue data on the page (assuming it is in a table)
revenue_table = soup.find('table', {'class': 'revenue-table'})  # Replace 'revenue-table' with the actual class name

# Convert the table to a pandas DataFrame
gamestop_revenue_data = pd.read_html(str(revenue_table))[0]

# Display the revenue data
print(gamestop_revenue_data.head())

# %%
import matplotlib.pyplot as plt

# Assuming you have already extracted the stock and revenue data as 'tesla_stock_data' and 'tesla_revenue_data'

# Plotting Tesla's stock price
plt.figure(figsize=(12, 6))
plt.plot(tesla_stock_data.index, tesla_stock_data['Close'], label='Stock Price', color='b')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Tesla Stock Price')
plt.legend()

# Plotting Tesla's revenue data
plt.figure(figsize=(12, 6))
plt.plot(tesla_revenue_data['Date'], tesla_revenue_data['Revenue'], label='Revenue', color='g')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.title('Tesla Revenue')
plt.legend()

plt.show()

# %%
# Assuming you have already extracted the stock and revenue data as 'gamestop_stock_data' and 'gamestop_revenue_data'

# Plotting GameStop's stock price
plt.figure(figsize=(12, 6))
plt.plot(gamestop_stock_data.index, gamestop_stock_data['Close'], label='Stock Price', color='b')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('GameStop Stock Price')
plt.legend()

# Plotting GameStop's revenue data
plt.figure(figsize=(12, 6))
plt.plot(gamestop_revenue_data['Date'], gamestop_revenue_data['Revenue'], label='Revenue', color='g')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.title('GameStop Revenue')
plt.legend()

plt.show()
